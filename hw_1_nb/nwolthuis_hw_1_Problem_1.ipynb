# %%
import numpy as np
print("for problem 2.10, ")
# Out:
# for problem 2.10,

# %%
#Semi-Empiracal Mass Formula, Problem 2.10 a
print("problem 2.10 a)")
A = int(input("please provide a positive integer value for A: "))
Z = int(input("please provide a positive integer value for Z: "))

#set up inital values
a1 = 15.8
a2 = 18.3
a3 = 0.714
a4 = 23.2
#set up value for a5 as a function of A and Z
if A%2 == 0:
    a5 = 12.0
else:
    a5 = 0
if Z%2 == 0:
    a5 = a5
else:
    a5 = a5 * (-1)
    
#Set up function for B
B = (a1*A) - (a2*(A**(2/3))) - a3*(Z**2)/(A**(1/3)) - (a4*((A-2*Z)**2)/A) + a5/(A**(1/2))
#Release the Krak- ... B value
print("the total binding energy is",B, "MeV")
# Out:
# problem 2.10 a)
# please provide a positive integer value for A: 58
# please provide a positive integer value for Z: 28
# the total binding energy is 497.5620206224374 MeV

# %%
#Semi-Empiracal Mass Formula, Problem 2.10 b
print("problem 2.10 b)")
A = int(input("please provide a positive integer value for A: "))
Z = int(input("please provide a positive integer value for Z: "))

#set up inital values
a1 = 15.8
a2 = 18.3
a3 = 0.714
a4 = 23.2
    
#set up value for a5 as a function of A and Z
if A%2 == 0:
    a5 = 12.0
else:
    a5 = 0
if Z%2 == 0:
    a5 = a5
else:
    a5 = a5 * (-1)
    
#Set up function for B
B = (a1*A) - (a2*(A**(2/3))) - a3*(Z**2)/(A**(1/3)) - (a4*((A-2*Z)**2)/A) + a5/(A**(1/2))
    
#show binding energy per nucleon
print("the binding energy per nucleon is", B/A, "MeV")
# Out:
# problem 2.10 b)
# please provide a positive integer value for A: 58
# please provide a positive integer value for Z: 28
# the binding energy per nucleon is 8.578655527973059 MeV

# %%
#Semi-Empiracal Mass Formula, Problem 2.10 c
print("problem 2.10 c)")
Z = int(input("please provide a positive integer value for Z: "))

#set up values for constants
a1 = 15.8
a2 = 18.3
a3 = 0.714
a4 = 23.2
    
A_list = []
b_list = []
#set up a loop for the value of A
for A in range(Z, 3*Z):
        
    #set up value for a5 as a function of A and Z in the loop
    if A%2 == 0:
        a5 = 12.0
    else:
        a5 = 0
    if Z%2 == 0:
        a5 = a5
    else:
        a5 = a5 * (-1)
        
    #Set up function for B in the loop
    B = (a1*A) - (a2*(A**(2/3))) - a3*(Z**2)/(A**(1/3)) - (a4*((A-2*Z)**2)/A) + a5/(A**(1/2))
        
    #Making lists for the A and associated B values
    A_list.append(A)
    b_list.append(B/A)
    
#determing the index for the maximum B value for a given Z
b_max_index = b_list.index(max(b_list))
    
#Pick out and print the A value with the most stable B value
print("The most stable value for A is", A_list[b_max_index], 'with a binding energy per nucleon of', max(b_list), "MeV")
# Out:
# problem 2.10 c)
# please provide a positive integer value for Z: 28
# The most stable value for A is 62 with a binding energy per nucleon of 8.70245768367189 MeV

# %%
print("problem 2.10 d)")
Zmax = int(input("please provide a maximum positive integer value for Z to loop through: "))

#making the lists for the b and Z value
high_b = []
Z_list = []
    
#starting the Z loop
for Z in range(1,Zmax + 1):
    #set up values for constants
    a1 = 15.8
    a2 = 18.3
    a3 = 0.714
    a4 = 23.2
    
    #make lists for values
    A_list = []
    b_list = []
    
    #set up a loop for the value of A
    for A in range(Z, 3*Z):
        
        #set up value for a5 as a function of A and Z in the loop
        if A%2 == 0:
            a5 = 12.0
        else:
            a5 = 0
        if Z%2 == 0:
            a5 = a5
        else:
            a5 = a5 * (-1)
        
        #Set up function for B in the loop
        B = (a1*A) - (a2*(A**(2/3))) - a3*(Z**2)/(A**(1/3)) - (a4*((A-2*Z)**2)/A) + a5/(A**(1/2))
        
        #Making list for B values
        b_list.append(B/A)
        A_list.append(A)
    
    #Pick out the high B values-
    high_b.append((max(b_list)))
        
    #Making list for Z values
    Z_list.append(Z)
    
    #Giving the stable A values for each value of Z
    print("for Z equals", Z_list[-1], "the most stable value for A is", A_list[b_list.index(max(b_list))])

#Determine Index number for the maximum binding energy for the Z value
max_index = high_b.index(max(high_b))

#adding a space between the A values for Z's and the most stable Z value for ease of reading
print()

#Delivering the final answer, after much blood sweat and tears, not actually because gross
print("the value of Z with the most stable binding energy is", Z_list[max_index])
# Out:
# problem 2.10 d)
# please provide a maximum positive integer value for Z to loop through: 100
# for Z equals 1 the most stable value for A is 2
# for Z equals 2 the most stable value for A is 4
# for Z equals 3 the most stable value for A is 7
# for Z equals 4 the most stable value for A is 8
# for Z equals 5 the most stable value for A is 11
# for Z equals 6 the most stable value for A is 14
# for Z equals 7 the most stable value for A is 15
# for Z equals 8 the most stable value for A is 18
# for Z equals 9 the most stable value for A is 19
# for Z equals 10 the most stable value for A is 22
# for Z equals 11 the most stable value for A is 25
# for Z equals 12 the most stable value for A is 26
# for Z equals 13 the most stable value for A is 29
# for Z equals 14 the most stable value for A is 30
# for Z equals 15 the most stable value for A is 33
# for Z equals 16 the most stable value for A is 36
# for Z equals 17 the most stable value for A is 37
# for Z equals 18 the most stable value for A is 40
# for Z equals 19 the most stable value for A is 43
# for Z equals 20 the most stable value for A is 44
# for Z equals 21 the most stable value for A is 47
# for Z equals 22 the most stable value for A is 48
# for Z equals 23 the most stable value for A is 51
# for Z equals 24 the most stable value for A is 54
# for Z equals 25 the most stable value for A is 55
# for Z equals 26 the most stable value for A is 58
# for Z equals 27 the most stable value for A is 61
# for Z equals 28 the most stable value for A is 62
# for Z equals 29 the most stable value for A is 65
# for Z equals 30 the most stable value for A is 68
# for Z equals 31 the most stable value for A is 69
# for Z equals 32 the most stable value for A is 72
# for Z equals 33 the most stable value for A is 75
# for Z equals 34 the most stable value for A is 76
# for Z equals 35 the most stable value for A is 79
# for Z equals 36 the most stable value for A is 82
# for Z equals 37 the most stable value for A is 85
# for Z equals 38 the most stable value for A is 86
# for Z equals 39 the most stable value for A is 89
# for Z equals 40 the most stable value for A is 92
# for Z equals 41 the most stable value for A is 93
# for Z equals 42 the most stable value for A is 96
# for Z equals 43 the most stable value for A is 99
# for Z equals 44 the most stable value for A is 102
# for Z equals 45 the most stable value for A is 103
# for Z equals 46 the most stable value for A is 106
# for Z equals 47 the most stable value for A is 109
# for Z equals 48 the most stable value for A is 110
# for Z equals 49 the most stable value for A is 113
# for Z equals 50 the most stable value for A is 116
# for Z equals 51 the most stable value for A is 119
# for Z equals 52 the most stable value for A is 120
# for Z equals 53 the most stable value for A is 123
# for Z equals 54 the most stable value for A is 126
# for Z equals 55 the most stable value for A is 129
# for Z equals 56 the most stable value for A is 130
# for Z equals 57 the most stable value for A is 133
# for Z equals 58 the most stable value for A is 136
# for Z equals 59 the most stable value for A is 139
# for Z equals 60 the most stable value for A is 140
# for Z equals 61 the most stable value for A is 143
# for Z equals 62 the most stable value for A is 146
# for Z equals 63 the most stable value for A is 149
# for Z equals 64 the most stable value for A is 150
# for Z equals 65 the most stable value for A is 153
# for Z equals 66 the most stable value for A is 156
# for Z equals 67 the most stable value for A is 159
# for Z equals 68 the most stable value for A is 162
# for Z equals 69 the most stable value for A is 163
# for Z equals 70 the most stable value for A is 166
# for Z equals 71 the most stable value for A is 169
# for Z equals 72 the most stable value for A is 172
# for Z equals 73 the most stable value for A is 175
# for Z equals 74 the most stable value for A is 176
# for Z equals 75 the most stable value for A is 179
# for Z equals 76 the most stable value for A is 182
# for Z equals 77 the most stable value for A is 185
# for Z equals 78 the most stable value for A is 188
# for Z equals 79 the most stable value for A is 191
# for Z equals 80 the most stable value for A is 192
# for Z equals 81 the most stable value for A is 195
# for Z equals 82 the most stable value for A is 198
# for Z equals 83 the most stable value for A is 201
# for Z equals 84 the most stable value for A is 204
# for Z equals 85 the most stable value for A is 205
# for Z equals 86 the most stable value for A is 208
# for Z equals 87 the most stable value for A is 211
# for Z equals 88 the most stable value for A is 214
# for Z equals 89 the most stable value for A is 217
# for Z equals 90 the most stable value for A is 220
# for Z equals 91 the most stable value for A is 223
# for Z equals 92 the most stable value for A is 224
# for Z equals 93 the most stable value for A is 227
# for Z equals 94 the most stable value for A is 230
# for Z equals 95 the most stable value for A is 233
# for Z equals 96 the most stable value for A is 236
# for Z equals 97 the most stable value for A is 239
# for Z equals 98 the most stable value for A is 242
# for Z equals 99 the most stable value for A is 243
# for Z equals 100 the most stable value for A is 246
#
# the value of Z with the most stable binding energy is 28
